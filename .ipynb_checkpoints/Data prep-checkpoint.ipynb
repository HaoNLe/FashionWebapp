# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models

import numpy as np
from PIL import Image
from io import BytesIO

# %%
dataset_name = 'AmazonFashion6ImgPartitioned.npy'
[user_train, user_validation, user_test, Item, usernum, itemnum] = np.load(dataset_name, encoding='bytes')

# %%
Item[100300]
# Out:
# {b'asin': b'B00CNFRIFA',
#  b'c': array([False,  True, False,  True, False, False]),
#  b'categories': [[b'Clothing, Shoes & Jewelry',
#    b'Girls',
#    b'Clothing',
#    b'Dresses',
#    b'Playwear']],
#  b'imUrl': b'http://ecx.images-amazon.com/images/I/41jQSUFbTAL._SX342_.jpg',
#  b'imgs': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00CV\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x01\x02\x03\x06\x07\x08\xff\xc4\x00>\x10\x00\x02\x02\x01\x03\x03\x02\x04\x03\x07\x02\x04\x06\x03\x01\x00\x01\x02\x00\x03\x11\x04\x12!\x051A\x13Q"2aq\x06\x14\x81#B\x91\xa1\xb1\xc1\xd13R\x15b\x82\xe1\x07$CSr\xf0\x16c\xd2\xf1\xff\xc4\x00\x1b\x01\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x05\x06\x07\xff\xc4\x005\x11\x00\x02\x02\x01\x03\x03\x01\x06\x05\x03\x04\x03\x01\x00\x00\x00\x00\x01\x02\x03\x11\x04\x12!\x051AQ\x13"2aq\x91\x06\x14\x81\xa1\xd1\xc1\xe1\xf0#3S\xb1\x16Rr\xf1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfd\x97\x11\x10\x04D@\x11\x11\x00DG0\x04D@\x11\x11\x00DD\x01<\xf7\xe3\xaa\xed~\x8c\xbe\x8e7\x0bA#\xe9\x83=\x0c\xa1\xfcl,= zd\x86\xf5\x01\xe3\xf5\x9c\xee\xac\x93\xd1X\x9f\xa7\x82\xca\x9e&\x8f;\xd3\x99\xd8%\x8cv\xfb\xe6{\x1e\x8a\xe8\xda0\xa8\xdb\x82\xb1\xe7\xef\xcf\xf7\x9eG\xa5\xd7\xe8\x06RI\x07\x9ee\xefCu\xd3\xde\xe0\x92\x16\xce\xfe\xc0\xcewA\x84\xe3J\xca\xfa\x93\xbd\xad\xc7\xa0\x89\x80A\x19\x1c\xcc\xcfDP""\x00\x882\x07S\xea\t\xa5\xa1\x99~&\xfas\x8f\xac\x02\x07U\xb3\xd5\xd62\x83\x9d\x9f\x08\x02B\xb1(\xac\x1bo(\x02\xf2Kx\x9b\xd5\x7f\xac\xa1\xeb`\xca\xfc\xee\x1ef-\xf4U\x0f\xa8\xa1\xc0\xe4\xee\xe4I\xbf\x87(\x17\xfd)\xab~\x9fC\xd2A\xad\x902\x91\xe4\x19*G\xe9\xc4\xb6\x86\x86#i5\x83\x8fn$\x89\x00""\x00\x88\x88\x02" \x08\x88\x80""\x00\x88\x88\x02" \x08\x88\x80""\x00\x88\x88\x03\x11\x88\x88\x02" \x08\x88\x80""\x00\x88\x88\x02U\xfe#E\xb3F\x88\xdd\x8d\xa3\xfa\x19i*:\xed\x99\xb6\xba\xf3\xc2\x82H\xfa\xc8\xce\xb5dv\xbf#8*\x1e\xbd\x8cJ\xaeA\xf11\xa5\xd5\xd1k\xb5J\xdbm\x1d\xd1\x86\x0f\xfd\xe7o8\x9a\xbdh\xc01\xadY\x81\xc8\xc8\xed1\r7\xb2\x93\x94<\x86\xf2gY\xaa\xd5\xd5R%\x16\xb2\x12q\x9c\xf6\xe2v\xa7\xacj\xbd5\xde\xc3y]\xc4\x15\x90\x98\xda\xc4z\xa1A\x07#\x06p\xd6[]eYJ\x96\x00\xae;\xf7\x94j5\x15\xd0\xdc\xe7,\x19\x8c[\xecZ\xf4\xee\xb1\xad\xd5\xe9\x12\xdd\xa8\xa5\xb3\xfb\xbfR\'v\xd7kI\xc1p\xbfa"\xf4\xb5\xae\x8d\x05u\xae\x0e\xd02}\xcf\x99\xda\xc6R\x0f3j\x99)\xc1H\x8b\xf9\x9aY\xab\xb5\xc9\x06\xe78\xe1\xb9\x95\xfdA\xaf\xb6\x82\x94\xe3{\x1d\xb9>3\xdc\xff\x00\t\xb5\r\xbe\xddF\x0e@|\x7f)&\xb4\x07\x9f\x139\xdd\x07\x80gI\xa6M6\x91Pp\x95\xae\x07>\x00\x90\xa8\xaa\xcb\xae-v\xe0\x84\xf0\xb9\xc7\x9e\'K\xf5\x95\xadmU\x8d\xb0\x06\x03\x9f>q3\xa2\xd5R\x1c\xd9n\xf0\x99\xc6\xe2\x87o\xf1\x9c\xe5\xa8\xa3Q8\xc3w\xc3\xe3\xf9,\xc3\x8a\xe4\xf5Z2?-^?\xda\'Y\x1b\xa7\xb8zF;\x03$\xce\x81\x01\x11\x10\x04D@\x11\x11\x00DD\x01\x11\x10\x04D@\x11\x11\x00DD\x01\x11\x10\x04D@\x11\x11\x00DG\x98\x02" \x08\x88\x80""\x01\x87`\x8aY\x88\x00rI\x9ecY\xab[\xf5\xcf\xb82\x12~\x1d\xdd\x98x \xcbn\xbfc.\x95T\x0c\x87l\x11\xef\xc1\x94x\\\xfaL2\x84eA\x1d\x87\xb4\x94S\xcf\x06\x0e\xa4\xe2d`s+(\xd3\xe7R\xf5\x8aA\xadO\t\x8c\x11\xfa\xfbK5\xd1TG\xfabF\xbb\x9c\xf3\xc7`\xd6\r\x1f\xe2\xc9\xc7o\xa4\xf3\xba\xaa\xad\xbe\xeb.\xa9\x9d9\x00\x02?\x8f3\xd3\x9d0PU\x17\x1fn\'1\xa6\'$&\t\xf7\xf3<\xff\x00Y\xe9vk\xb1\x19>\r\x8a-U\xf2s\xe9U=zDG\xcf\xb9\x99\xd5\xd9\xe9V\xee\x06|\x01\xeed\x9c\xb7\xa2\x05hX\x1fn\xd3\x85\x95Z\xf8"\xa1\x91\xdb\'\xb4\xec\xe8\xe8\xfc\xbe\x9e5/\x08\xa2R\xdc\xdb \r\xf4\xbe\x96\xb0Ir\xc4\xbf\xd4c\x93&\x0b\xb7e)\xc3>pO\x85\x98\x1a&\xce\xeb\x88v>\xc3\x02\x11\xc8\xea?\x95E\xf8V\xbd\xcd\x8f\x07<K\xa2\x9c\x7fS\x06\x06\x82\x8d\x80\x15.\xc5\x8b\x12O\x93\xe6X\xe94\xcbML9 \x8e\xc7\x99\x8a ...
#  b'related': {b'also_bought': [b'B00CNFRD2I',
#    b'B00D69VJ7K',
#    b'B00G3UZ286',
#    b'B009YB309Y',
#    b'B00GFAK74I',
#    b'B00B24EOLE',
#    b'B00BXT4D64',
#    b'B009YAYO40',
#    b'B00B2GVPFU',
#    b'B00AARL3UY',
#    b'B00CN38IAG',
#    b'B00GCPSQQ2',
#    b'B00FU8WGBS',
#    b'B009YAYWTM',
#    b'B00II6ZHXS',
#    b'B00I3GPVV6',
#    b'B00BXQTQ2I',
#    b'B00EW45UKK',
#    b'B00D69UWW8',
#    b'B00EGSNBX0',
#    b'B00HKKS13Q',
#    b'B00EJVAGB4',
#    b'B00DSJ6FCM',
#    b'B00960XCAK',
#    b'B00CTPPZMM',
#    b'B00EPKC24S',
#    b'B00BBQG6W8',
#    b'B00EGSF4VM',
#    b'B00ESMW5EU',
#    b'B00AV3Z362',
#    b'B00GFAKJLO',
#    b'B009Y8YCAS',
#    b'B00BXT5MD2',
#    b'B00E6SM9JM',
#    b'B009YAYFEO',
#    b'B009YB2YUU',
#    b'B00EQZRT0E',
#    b'B009YB0B8W',
#    b'B00EGSF7G4',
#    b'B00FURFBXE',
#    b'B009YB18RK',
#    b'B00EPKCZ22',
#    b'B00AARNCC6',
#    b'B009YB1F7I',
#    b'B009YAZM2S',
#    b'B009YB5SSA',
#    b'B00960XQTM',
#    b'B009YB0V46',
#    b'B00DYRHU4K',
#    b'B00ETCLOZK',
#    b'B009AHH8D6',
#    b'B002R0FABA',
#    b'B005FULYOQ',
#    b'B0057MF3Y4',
#    b'B006RBEC5K'],
#   b'also_viewed': [b'B00CN38IAG',
#    b'B00CNFRD2I',
#    b'B00D69VJ7K',
#    b'B009YAYO40',
#    b'B009YB309Y',
#    b'B00B24EOLE',
#    b'B00D69UWW8',
#    b'B009YAYWTM',
#    b'B00B2GVPFU',
#    b'B00II6ZHXS',
#    b'B00BXQTQ2I',
#    b'B00IVUWPH2',
#    b'B00BXT4D64',
#    b'B00GFAK74I',
#    b'B00BV9JZIW',
#    b'B00AARNCC6',
#    b'B00G3UZ286',
#    b'B00B20MKAA',
#    b'B009YB2YUU',
#    b'B00960VQIK',
#    b'B00EGSN6FS',
#    b'B00GFAKOYQ',
#    b'B009YAYFEO',
#    b'B00II6Z3KU',
#    b'B00E6SM9JM',
#    b'B00F778F7Q',
#    b'B00F77M5FO',
#    b'B00ESMW5EU',
#    b'B00DSJ6FCM',
#    b'B00EGSNBX0',
#    b'B00BXT5MD2',
#    b'B00AARL3UY',
#    b'B00F778B9I',
#    b'B00B20M7L2',
#    b'B00E30VU84',
#    b'B00EJTLDFE',
#    b'B00960XCAK',
#    b'B009YB5SSA',
#    b'B00BBRTAD4',
#    b'B00D3U3GPK',
#    b'B00GFAKJLO',
#    b'B00CIB5W8O',
#    b'B00EVF2TR2',
#    b'B00CFQVMAO',
#    b'B00HY2RILQ',
#    b'B00960XS72',
#    b'B00HXZG3DI',
#    b'B009YB60LY',
#    b'B00EVF2K2G',
#    b'B009YB18RK',
#    b'B00F77M7PC',
#    b'B009YB6A1E',
#    b'B00EGSF7G4',
#    b'B00J72VE4S',
#    b'B00EJVAGB4',
#    b'B00F7781NY',
#    b'B00BT0FZAU',
#    b'B009YAZM2S'],
#   b'bought_together': [b'B00CNFRD2I',
#    b'B00D69VJ7K',
#    b'B009YB309Y',
#    b'B00B24EOLE']},
#  b'salesRank': {b'Clothing': 35971},
#  b'title': b'3 Layers Girls Dress Sunflower Wave Pageant Bridesmaid'}

# %%
allCats1 = set()
allCats2 = set()

for key, value in Item.items():
    catLists = value[b'categories']
    for catList in catLists:
        i = 0
        for cat in catList:
            if len(allCats1) < 1000:
                allCats1.add(cat)
            elif cat not in allCats1:
                allCats2.add(cat)

# %%
allCats1
# Out:
# {b'Isaac Mizrahi',
#  b'Island Surf',
#  b'Outdoor',
#  b'Motorcycle & ATV Casual Footwear',
#  b'Full Price',
#  b'Active',
#  b'Petite',
#  b'Keyrings & Keychains',
#  b'KangaROOS',
#  b'Muck Boot',
#  b'Dyeables',
#  b'BIG BUDDHA',
#  b'adidas',
#  b'Havaianas',
#  b'The Flexx',
#  b'Coats & Jackets',
#  b'Bacco Bucci',
#  b'Worishofer',
#  b'Alejandro Ingelmo',
#  b'Cardigans',
#  b'Flat Front',
#  b'Protective Gear',
#  b'Chippewa',
#  b'UGG',
#  b'NaNa',
#  b'Speedo',
#  b'Birkenstock',
#  b'Calvin Klein',
#  b'Californians',
#  b'Tennis',
#  b'Walking',
#  b'Amalfi by Rangoni',
#  b'Kork-Ease',
#  b'Sport Coats & Blazers',
#  b'Pink Studio',
#  b'Shirts',
#  b'Footwear',
#  b'Dingo',
#  b'Reebok',
#  b'BCBGMAXAZRIA',
#  b'Gotta Flurt',
#  b'Fergie',
#  b'California Magdesians',
#  b'Touch Ups',
#  b'ULU',
#  b'Tracy Reese',
#  b'Wild Diva',
#  b'Dr. Martens',
#  b'Unlisted',
#  b'Sunglasses',
#  b'Me Too',
#  b'Board Games',
#  b'Affliction',
#  b'Miss Me',
#  b'Sleepwear & Robes',
#  b'JUMP',
#  b'DC',
#  b'Stacy Adams',
#  b'The Highest Heel',
#  b'Scarpe Diem',
#  b'Rain Footwear',
#  b'Safety & Security',
#  b'Etienne Aigner',
#  b'Hand Tools',
#  b'David Tate',
#  b'Prince',
#  b'Dockers',
#  b'N.Y.L.A.',
#  b'Woolrich',
#  b'Robert Clergerie',
#  b'Allrounder by Mephisto',
#  b'SHANE&SHAWN',
#  b'Grasshoppers',
#  b'Simple',
#  b'Kalliste',
#  b'Kenneth Cole REACTION',
#  b'F',
#  b'Nanette Lepore',
#  b'Dance',
#  b'DSQUARED2',
#  b'Harajuku Lovers',
#  b'Mother of the Bride Dresses',
#  b'Beauty',
#  b'Manitobah Mukluks',
#  b'Exotic Apparel',
#  b'CL by Chinese Laundry',
#  b'Tuxedo Shirts',
#  b'Tuxedos',
#  b'Backpacking Boots',
#  b'Giuseppe Zanotti',
#  b'Suit Jackets',
#  b'Prevata',
#  b'Jackets & Coats',
#  b'Shearling',
#  b'Shoelaces',
#  b'COACH',
#  b'A. Marinelli',
#  b'Kenetrek',
#  b'HARAJUKU LOVERS',
#  b'Timberland PRO',
#  b'Lelli Kelly',
#  b'Aquaz',
#  b'Tecnica',
#  b'La Canadienne',
#  b'Blazers & Jackets',
#  b'Snowboarding',
#  b'Palladium',
#  b'Eject',
#  b'Scarpa',
#  b'Active & Performance',
#  b'Health Care & Food Service',
#  b'Loafers & Slip-Ons',
#  b'Sam Edelman',
#  b'KIDORABLE',
#  b'Mules & Clogs',
#  b'Night Out & Cocktail',
#  b'FOSSIL',
#  b'Lightweight Jackets',
#  b'Madden Girl',
#  b'French Sole FS/NY',
#  b'Swear',
#  b'TATAMI',
#  b'Columbia',
#  b'Miss Sixty',
#  b'Trotters',
#  b'Saucony',
#  b'Ben Sherman',
#  b'Jumpsuits, Rompers & Overalls',
#  b'Menbur',
#  b'Robert Wayne',
#  b'Jerseys',
#  b'Naughty Monkey',
#  b'Anoraks',
#  b'Red Wing Shoes',
#  b'Michael Toschi',
#  b'Luna Rosa',
#  b'Exercise & Fitness',
#  b'Sandals',
#  b'Bernardo',
#  b'Original Penguin',
#  b'Shrugs',
#  b'Maloles',
#  b'Plus-Size',
#  b'Staheekum',
#  b'Toys & Games',
#  b'LOEFFLER RANDALL',
#  b'Shoe Horns & Boot Jacks',
#  b'Clothing Sets',
#  b'DV by Dolce Vita',
#  b'Snow Sports',
#  b'Down & Down Alternative',
#  b'Romano Martegani',
#  b'Dekline',
#  b'Onex',
#  b'Squash',
#  b'FOOTPRINTS',
#  b'Think!',
#  b'BLVD',
#  b'Jack Rogers',
#  b'Maternity',
#  b'Ruthie Davis',
#  b'Tibi',
#  b'Camilla Skovgaard London',
#  b'Rachel Shoes',
#  b'Inov-8',
#  b'Rain',
#  b'Candela',
#  b'One of 2',
#  b'Bearpaw',
#  b'Hiking Boots',
#  b'Track & Field & Cross Country',
#  b'Q',
#  b'Sport Sandals',
#  b'Designer Shoes & Handbags',
#  b'Trail Running',
#  b'Steve Madden',
#  b'Boots',
#  b'Shoe Care & Accessories',
#  b'Down & Parkas',
#  b'Aussie Dogs',
#  b'pediped',
#  b'Polliwalks',
#  b'L.A.M.B.',
#  b'Madison Harding',
#  b'Medical Supplies & Equipment',
#  b'Handkerchiefs',
#  b'Button-Down Shirts',
#  b'Rip Curl',
#  b'Icebug',
#  b'Joseph Griffin',
#  b'Snow Boots',
#  b'Insulated',
#  b'PF Flyers',
#  b'Report',
#  b'Fishing',
#  b'crocs',
#  b'DVS',
#  b'Studio Pollini',
#  b'Groundhog',
#  b'Blondo',
#  b'Loafers',
#  b'Auri',
#  b'Bogs',
#  b'XOXO',
#  b'HKNB Heidi Klum for New Balance',
#  b'Bettye Muller',
#  b'Oilily',
#  b'Baby Dolls',
#  b'Rocawear',
#  b'Rebecca Taylor',
#  b'GBX',
#  b'Callaway',
#  b'SWIMS',
#  b'Fur & Faux Fur',
#  b'Azura',
#  b'Stuart Weitzman',
#  b'Amiana',
#  b'Rebels',
#  b'Jumping Jacks',
#  b'Leather & Faux Leather',
#  b'Camping & Hiking',
#  b'Rafters',
#  b'Jo Ghost',
#  b'DKNY',
#  b'ASGI',
#  b'Vasque',
#  b'Novelty, Costumes & More',
#  b'DKNYC',
#  b'One-Pieces',
#  b'Rieker',
#  b'Water Shoes',
#  b'Trench & Rain',
#  b'Tundra',
#  b'Ciao Bimbi',
#  b'Bibs',
#  b'Libby Edelman',
#  b'Almarino',
#  b'Be & D',
#  b'Hunting',
#  b'Diba',
#  b'Helle Comfort',
#  b'BeautiFeel',
#  b'UNIONBAY',
#  b'Naturino',
#  b'Dress',
#  b'Made in USA',
#  b'John Deere',
#  b'Cheerleading',
#  b'oh DEER!',
#  b'Liliana',
#  b'Impo',
#  b'J',
#  b'Kamik',
#  b'Kooba',
#  b'Hale Bob',
#  b'Skiing',
#  b'Barefoot Tess',
#  b'Garmont',
#  b'Fishing Wear & Apparel',
#  b'Lucky Brand',
#  b'Jean Paul Gaultier',
#  b'Fitness & Cross-Training',
#  b'Polos',
#  b'Sigerson Morrison',
#  b'JP and Mattie',
#  b'Grazie',
#  b'IZOD',
#  b'Top-Handle Bags',
#  b'Casadei',
#  b'Chooka',
#  b'Hi-Tec',
#  b'Outerwear',
#  b'G',
#  b'Claudia Ciuti',
#  b'Stonefly',
#  b'Puma',
#  b'Renzo Fontanelli',
#  b'MUK LUKS',
#  b'Teva',
#  b'Golden Retriever',
#  b'Charlie 1 Horse',
#  b'Element',
#  b'Sneakers',
#  b'Tools & Home Improvement',
#  b'Yoga',
#  b'Rain Boots',
#  b'Basketball',
#  b'Modern Vintage',
#  b'Unisa',
#  b'Motorcycle & Powersports',
#  b'Cardigan',
#  b'J-41',
#  b'Tapeet by Vicini',
#  b'Games',
#  b'De Osu',
#  b'Cape Clogs',
#  b'Fan Shop',
#  b'Boating & Water Sports',
#  b'Ocean Minded',
#  b'Roberto Guerrini',
#  b'Kickers',
#  b'Belle by Sigerson Morrison',
#  b'Racquetball',
#  b'Hush Puppies',
#  b'Enzo Angiolini',
#  b'LeSportsac',
#  b'Calle',
#  b'Hype',
#  b'Fashion Sneakers',
#  b'Royal Elastics',
#  b'Aquatalia by Marvin K.',
#  b'Chaco',
#  b'Ellen Tracy',
#  b'Wolverine',
#  b'Madeline',
#  b'Calvin Klein Test Store',
#  b'Rain Wear',
#  b'H',
#  b'Dirty Laundry',
#  b'Fiel',
#  b'GUESS',
#  b'Rainbow Sandals',
#  b'Pony',
#  b'Oboz',
#  b'Sports & Outdoors',
#  b'bebe',
#  b'Ann Marino',
#  b'Magnanni',
#  b'FLY London',
#  b'Women',
#  b'Field Hockey & Lacrosse',
#  b'Household Supplies',
#  b'Clothing, Shoes & Jewelry',
#  b'B',
#  b'Restricted',
#  b'Stetson',
#  b'Rocket Dog',
#  b'Blouses',
#  b'Tommy Bahama',
#  b'Equestrian Sports',
#  b'Pants',
#  b'FitFlop',
#  b'Celeste',
#  b'Liz Rene Couture',
#  b'Active Sweatshirts',
#  b'Re-Mix Vintage',
#  b'Natural Sport',
#  b'Clarks',
#  b'Arche',
#  b'IPATH',
#  b'Badgley Mischka',
#  b'London Fog',
#  b'Oakley',
#  b'Report Signature',
#  b'Keen',
#  b'Aerosoles',
#  b'Old Friend',
#  b'ALDO',
#  b'Barbie',
#  b'smartdogs',
#  b'indigo by Clarks',
#  b'Josmo',
#  b'Groove',
#  b'MICHAEL Michael Kors',
#  b'Sweatshirts',
#  b'Minnetonka',
#  b'Shimano',
#  b'Comfort Shoes',
#  b'ROGUE',
#  b'Eric Michael',
#  b'Fly Flot',
#  b'Lucchese',
#  b'Jeans',
#  b'Hats & Caps',
#  b'Cienta',
#  b'Timberland',
#  b'OTBT',
#  b'Paul Green',
#  b'Duck Head',
#  b'Fleece Jackets',
#  b'Magnum',
#  b'El Naturalista',
#  b'Foamtreads',
#  b'Band & Music Fan',
#  b'Evolv',
#  b'Heyday',
#  b'Liz Claiborne',
#  b'Miz Mooz',
#  b'Khombu',
#  b'Gwyneth Shoes',
#  b'Accessories',
#  b'Wedding Dresses',
#  b'Racquet Sports',
#  b'Sunglasses & Eyewear Accessories',
#  b'Laura Brandon',
#  b'School Uniforms',
#  b'Spring Event',
#  b'Area Forte',
#  b'Dress Coats',
#  b'Pampili',
#  b'Wrestling',
#  b'Cargo',
#  b'Summer Event',
#  b'Irregular Choice',
#  b'Equestrian Sport Boots',
#  b'Taos',
#  b'Fashion Sweatshirts',
#  b'Chie Mihara',
#  b'Underwear',
#  b'Industrial & Construction',
#  b'P',
#  b'Bustiers & Corsets',
#  b'C1RCA',
#  b'Ryka',
#  b'Akademiks',
#  b'Skateboarding',
#  b'Bostonian',
#  b'Fahrenheit',
#  b'dav',
#  b'Tingley',
#  b'Ros Hommerson',
#  b'Tignanello',
#  b'Button-Down & Dress Shirts',
#  b'Tretorn',
#  b'W',
#  b'K-Swiss',
#  b'Stride Rite',
#  b'Kelsi Dagger',
#  b'Dinosoles',
#  b'olsenHaus',
#  b'Osiris',
#  b'Suits & Blazers',
#  b'Sperry Top-Sider',
#  b'See Kai Run',
#  b'GoLite',
#  b'Motorcycle',
#  b'Juicy Couture',
#  b'Diesel',
#  b'Boot Shop',
#  b'Finn Comfort',
#  b'Other Sports',
#  b'Dolce Vita',
#  b'Luiza Barcelos',
#  b'Carhartt',
#  b'Mea Shadow',
#  b'Blowfish',
#  b'Gee WaWa',
#  b'Blouses & Button-Down Shirts',
#  b'Sandro Moscoloni',
#  b'Cycling',
#  b'Wenger',
#  b'Nina',
#  b'Cindy Says',
#  b'Hatley',
#  b'Kids & Baby',
#  b'Skechers',
#  b'EMU Australia',
#  b'Kenneth Cole',
#  b'Clothing',
#  b'Easy Street',
#  b'Sbicca',
#  b'Overalls & Coveralls',
#  b'Kneepads',
#  b'Winter Promo',
#  b'Draven',
#  b'Cordani',
#  b'Mezlan',
#  b'Impulse',
#  b'Sam & Libby',
#  b'Australia Luxe Collective',
#  b'Klogs',
#  b'Pazzo',
#  b'Chukka',
#  b'Clogs & Mules',
#  b'Denim Jackets',
#  b'Football',
#  b'Hiking Shoes',
#  b'Easy Spirit',
#  b'Matisse',
#  b'Laredo',
#  b'School Issue',
#  b'Pierre Dumas',
#  b'Spring Promo',
#  b'N',
#  b'Cotton',
#  b'Spring Step',
#  b'Tanks & Camis',
#  b'Moda Spana',
#  b'Chocolat Blu',
#  b'Annie',
#  b'Brooks',
#  b'Boy Meets Girl',
#  b'Summer Promo',
#  b'Masks',
#  b'Oxfords',
#  b'Luggage & Travel Gear',
#  b'Kathryn Kerrigan',
#  b'Beyond Skin',
#  b'Wear to Work',
#  b'ECCO',
#  b'Pleaser',
#  b'Everybody',
#  b'Bowling',
#  b'Penny Loves Kenny',
#  b'J.Renee',
#  b'Gabor',
#  b'Suits & Sport Coats',
#  b'Work & Safety',
#  b'Fox',
#  b'Zodiac',
#  b'Playwear',
#  b'Pour La Victoire',
#  b'MBT',
#  b'Dezario',
#  b'Penthouse',
#  b'Tahari',
#  b'BALLY',
#  b'Health & Personal Care',
#  b'Wash',
#  b'Body Glove',
#  b'Hunting & Fishing',
#  b'Shoe & Boot Trees',
#  b'Northside',
#  b'Irish Setter',
#  b'Athletic Socks',
#  b'T.U.K.',
#  b'Active Skirts',
#  b'Work Utility & Safety',
#  b'Costumes & Accessories',
#  b'Western Chief',
#  b'Klub Nico',
#  b"WF Inheritance Test Women's CK Custom Store",
#  b"Women's Luxury Brands",
#  b'Joy Chen',
#  b'Baby Girls',
#  b'Ragg',
#  b'Shapewear',
#  b'Michael Antonio',
#  b'Miss Robertson',
#  b'Patricia Green',
#  b'Harley-Davidson',
#  b'thirtytwo',
#  b'FRYE',
#  b'Cocobelle',
#  b'Lovely People',
#  b'BC Footwear',
#  b'Josef Seibel',
#  b'Robert Zur',
#  b'Kenneth Cole New York',
#  b'Fashion Hoodies & Sweatshirts',
#  b'Roxy',
#  b'Zengara',
#  b'Versace',
#  b'Sudini',
#  b'necessary objects',
#  b'Rockport',
#  b'Skirts, Scooters & Skorts',
#  b'Jackets',
#  b'Vegetarian',
#  b'7 For All Mankind',
#  b'Luxury Rebel',
#  b'Handbags & Wallets',
#  b'BCBGirls',
#  b'Belvedere',
#  b'Seychelles',
#  b'S',
#  b'Five Ten',
#  b'Baby',
#  b'Golf',
#  b'Camper',
#  b'Vests',
#  b'Hunter',
#  b'Dansko',
#  b'Cynthia Vincent',
#  b'Dance Class',
#  b'Donna Karan',
#  b'Mizuno',
#  b'Charles Albert',
#  b'Flats',
#  b'Cougar',
#  b'Altama',
#  b'Ivanka Trump',
#  b'Caparros',
#  b'New Balance',
#  b'Tunics',
#  b'Charles by Charles David',
#  b'Tops',
#  b'Island Slipper',
#  b'Bella Vita',
#  b'Caterpillar',
#  b'Movie & TV Fan',
#  b'Patagonia',
#  b'Dunham',
#  b'Bath & Body',
#  b'Jambu',
#  b'Scully',
#  b'Reed Evins',
#  b'Lamo',
#  b'Sag Harbor',
#  b'Ted Baker',
#  b'Tic-Tac-Toes',
#  b'Garvalin',
#  b'dollhouse',
#  b'Via Spiga',
#  b'umi',
#  b'Quiksilver',
#  b'Old Gringo',
#  b'T-Shirts',
#  b'Samanta',
#  b'PRO-Keds',
#  b'Winter Event',
#  b'Arturo Chiang',
#  b'Casual',
#  b'Pilar Abril',
#  b'Tuxedo Jackets',
#  b'1803',
#  b'Tommy Hilfiger',
#  b'E',
#  b'Giesswein',
#  b'John Fluevog',
#  b'Swim',
#  b'P.W. Minor',
#  b'L.B. Evans',
#  b'Laura Ashley',
#  b'Nara Shoes',
#  b'zinc',
#  b'Denim',
#  b'Roper',
#  b'Apepazza',
#  b'Riding Boots',
#  b'Carlos by Carlos Santana',
#  b'Vogue',
#  b'Riding',
#  b'Outdoor Gear',
#  b'Fleece',
#  b'Active Shorts',
#  b'ARA',
#  b'Misbehave',
#  b'Two Lips',
#  b'Skins',
#  b'Knits & Tees',
#  b'Converse',
#  b'Volleyball',
#  b'Athena Alexander',
#  b'Paris Hilton',
#  b'Varsity Jackets',
#  b'Ergonomic Supports',
#  b'Western',
#  b'Night Out & Special Occasion',
#  b'GUESS by Marciano',
#  b'Santana',
#  b'Pant Sets',
#  b'Coconuts by Matisse',
#  b'U',
#  b'Velvet Angels',
#  b'Wilson',
#  b'80%20',
#  b'World Apparel',
#  b'Shorts',
#  b'Boutique 9',
#  b'R',
#  b'Sweaters',
#  b'Merrell',
#  b'Ballet & Dance',
#  b'farylrobin',
#  b'Wedding',
#  b'Bruno Magli',
#  b'Primigi',
#  b'Globe',
#  b'Bates',
#  b'Privo',
#  b'Girls',
#  b'Lava',
#  b'Durango',
#  b'Brass Boot',
#  b'Bronx',
#  b'Mossimo',
#  b'Pelle Moda',
#  b'Dreams',
#  b'Board Shorts',
#  b'Delman',
#  b'Dress Suits',
#  b'Matt Bernson',
#  b'Lauren Jones',
#  b'C',
#  b'Rampage',
#  b'Surf, Skate & Street',
#  b'Fred Perry',
#  b'Insulated & Down Jackets',
#  b'Safety Shoes',
#  b'MaxStudio',
#  b'Mountrek',
#  b'BCBGeneration',
#  b'D',
#  b'Intimates',
#  b'Naot',
#  b'VANELi',
#  b'Polo Shirts',
#  b'Breeches',
#  b'Esquivel',
#  b'Coclico',
#  b'Maui Surf Company',
#  b'Dresses',
#  b'Pantsuits',
#  b'Sugar',
#  b'Boating',
#  b'SOLE',
#  b'Joie',
#  b'Step & Stride',
#  b'Gentle Souls',
#  b'Beverly Feldman',
#  b'Wool & Blends',
#  b'Hiking & Trekking',
#  b'Tank Tops',
#  b'Sesto Meucci',
#  b'Colorful Creations',
#  b'Superga',
#  b'Deer Stags',
#  b'terrasoles',
#  b'Callisto',
#  b'Snow Wear',
#  b'Lingerie',
#  b'Capezio',
#  b'ACORN',
#  b'Pumps',
#  b'Athletic',
#  b'United Nude',
#  b'Poetic Licence',
#  b'Outerwear & Coats',
#  b'Diego di Lucca',
#  b'Special Occasion',
#  b'Allen Edmonds',
#  b'The SAK',
#  b'Windbreakers',
#  b'Betsey Johnson',
#  b'Exchange by Charles David',
#  b'Juniors',
#  b'Vibram',
#  b'Multitools & Accessories',
#  b'Shells',
#  b'Coloriffics',
#  b'MIA 2',
#  b'Sergio Zelcer',
#  b'Drew Shoe',
#  b'Sale Price',
#  b'Bass',
#  b'ExOfficio',
#  b'Charles David',
#  b'Scott David',
#  b'swedish hasbeens',
#  b'Leisure Sports & Game Room',
#  b'SOREL',
#  b'Shoe Fasteners & Laces',
#  b'Rosegold',
#  b'STEVEN by Steve Madden',
#  b'John Varvatos',
#  b'Men',
#  b'T',
#  b'0-9',
#  b'Street, Surf & Skate',
#  b'Diadora',
#  b'Marc by Marc Jacobs',
#  b'Skirt Suits',
#  b'Noel',
#  b'Born',
#  b'Socks',
#  b'ZiGiny',
#  b'La Plume',
#  b'Casual Button-Down Shirts',
#  b'Y',
#  b'To Boot New York',
#  b'Antelope',
#  b'Dressing Aids',
#  b'Pullovers',
#  b'Dress Shirts',
#  b'Fergalicious',
#  b'Lasonia',
#  b'Fleece Vests',
#  b'Luichiny',
#  b'Cudas',
#  b'Slippers',
#  b'ASICS',
#  b'soleRebels',
#  b'BLOCH',
#  b'Glaze',
#  b'Uniform Dress Shoes',
#  b'Dereon',
#  b'Henleys',
#  b'Fashion Hoodies',
#  b'Naturalizer',
#  b'X',
#  b'Rider',
#  b'Martinez Valero',
#  b'MIA',
#  b'Donald J Pliner',
#  b'Hoodies',
#  b'SoftWalk',
#  b'Wellco',
#  b'Franco Sarto',
#  b'Perlina',
#  b'LifeStride',
#  b'Work Wear & Uniforms',
#  b'Power & Hand Tools',
#  b'Keds',
#  b'tokidoki',
#  b'Matiko',
#  b'Polo Ralph Lauren',
#  b'Big & Tall',
#  b'Rough Justice',
#  b'Sebago',
#  b'Action Sports',
#  b'Household Cleaning',
#  b'Wild Rose',
#  b'Creative Recreation',
#  b'Le Chameau',
#  b'Military & Tactical',
#  b'Jumpsuits & Rompers',
#  b'Chinese Laundry',
#  b'Sports Sunglasses',
#  b'Kid Express',
#  b'Circa Joan & David',
#  b'Outdoor & Work',
#  b'Snow & Cold Weather',
#  b'Ciao Bella',
#  b'Southpole',
#  b'Shoes',
#  b'I',
#  b'Multitools',
#  b'M',
#  b'Daily Living Aids',
#  b'Etonic',
#  b'Georgina Goodman',
#  b'ESPRIT',
#  b'KATHY Van Zeeland',
#  b'Ed Hardy',
#  b'Suits',
#  b'Salomon',
#  b'A.Testoni',
#  b'Pajar',
#  b'Personal Protective Equipment',
#  b'Livie & Luca',
#  b'Koolaburra',
#  b'ALL BLACK',
#  b'Bodysuits',
#  b'Baseball & Softball',
#  b'nicole',
#  b'Aetrex',
#  b'Vincent',
#  b'Mudd',
#  b'L',
#  b'Blazers',
#  b'Spira',
#  b'Climbing',
#  b'Danner',
#  b'daniblack',
#  b'Lakai',
#  b'B. MAKOWSKY',
#  b'Brodie',
#  b'Fashion',
#  b'Jessica Simpson',
#  b'G by GUESS',
#  b'Shoe Care Kits & Sets',
#  b'London Underground',
#  b'Angel',
#  b'Safety Footwear',
#  b'Bourne',
#  b'Charles Jourdan Collection',
#  b'Geox',
#  b'Justin Boots',
#  b'Swimming',
#  b'Joan & David Collection',
#  b'Baby Boys',
#  b'Sanuk',
#  b'Bathing Accessories',
#  b'Willits',
#  b'Tsonga',
#  b'Energie',
#  b'Vision Street Wear',
#  b'Shoe Bags',
#  b'Tony Lama',
#  b'Skirt Sets',
#  b'Nine West',
#  b'Walking Cradles',
#  b'Ariat',
#  b'Not Rated',
#  b'Butter',
#  b'Pleated',
#  b'Nomad',
#  b'Novelty',
#  b'Yin',
#  b'Cole Haan',
#  b'Pullover',
#  b'Softball & Baseball',
#  b'TSUBO',
#  b'jessica bennett',
#  b'Soccer',
#  b'Ralph Lauren',
#  b'Florsheim',
#  b'O',
#  b'Buster Brown',
#  b'Joseph Abboud',
#  b'Tees',
#  b'Reef',
#  b'Punkrose',
#  b'Tanks Tops',
#  b'Nunn Bush',
#  b'Running',
#  b'Bandolino',
#  b'Lugz',
#  b'Zamberlan',
#  b'Automotive',
#  b'Fishing Boots Waders',
#  b'TapouT',
#  b'Anyi Lu',
#  b'Ray-Ban',
#  b'Versani',
#  b'Terra Plana',
#  b'Soda',
#  b'Tops & Tees',
#  b'Ramon Tenza',
#  b'Cri de Coeur',
#  b'Pastry',
#  b'Active Shirts & Tees',
#  b'Shoes & Accessories: International Shipping Available',
#  b'ZOO YORK',
#  b'Quilted Lightweight Jackets',
#  b'cobian',
#  b'Baby Phat',
#  b'Giorgio Brutini',
#  b'Montrail',
#  b'Fall Event',
#  b'Icon',
#  b'Bridesmaid Dresses',
#  b'Short Sets',
#  b'Dolce & Gabbana',
#  b'Shoe Brushes',
#  b'A-Line',
#  b'Barbo',
#  b'RJ Colt',
#  b'Blundstone',
#  b'R2',
#  b'Etnies',
#  b'Pura Lopez',
#  b'Bella',
#  b'Ash',
#  b'Lingerie, Sleep & Lounge',
#  b'Neil M',
#  b'Pearl iZUMi',
#  b'Dearfoams',
#  b'Heelys',
#  b'Pants & Capris',
#  b'Fila',
#  b'Mark Nason',
#  b'Scott Hawaii',
#  b'Papillio',
#  b'Thorogood',
#  b'LEGO',
#  b'Nike',
#  b'Boys',
#  b'LaCrosse',
#  b'Work Wear',
#  b'Z',
#  b'Jackets & Vests',
#  b'Grendha',
#  b'Rock & Republic',
#  b'Chelsea',
#  b'Volatile',
#  b'Eastland',
#  b'Combat',
#  b'adidas Originals',
#  b'Daniel Green',
#  b'Generic Surplus',
#  b'Proenza Schouler',
#  b'Nautica',
#  b'Haflinger',
#  b'Mootsies Tootsies',
#  b'Johnston & Murphy',
#  b'Loofahs, Sponges & Poufs',
#  b'Overalls',
#  b'Ecko Unltd.',
#  b'Little Laundry',
#  b'V',
#  b'Avia',
#  b'Gola',
#  b'Travel Accessories',
#  b'Oh!',
#  b'Baffin',
#  b'Corso Como',
#  b'Yellow Box',
#  b'Biviel',
#  b'Tools',
#  b'Skirts',
#  b'French Connection',
#  b'Suit Pants',
#  b'Vince Camuto',
#  b'rafe NEW YORK',
#  b'Nevados',
#  b'Dickies',
#  b'K',
#  b'Playboy'}

# %%
allCats2
# Out:
# {b'1.4.3. Girl',
#  b'A2Z Racer Gear',
#  b'Action Figures',
#  b'Action Figures & Statues',
#  b'Active Hoodies',
#  b'Active Pants',
#  b'Active Vests',
#  b'Adio',
#  b'Agatha Ruiz de la Prada',
#  b'Alberto Fermani',
#  b'Alexandra Neel',
#  b'Alife',
#  b'Alpro',
#  b'Amy Jo Gladstone',
#  b'Antik Batik',
#  b'Aroma Home',
#  b'Arts, Crafts & Sewing',
#  b'Artwork',
#  b'Aster',
#  b'Aura',
#  b'Avenger Safety Footwear',
#  b'BLUE BOTTLE',
#  b'Bags & Cases',
#  b'Banana Blues',
#  b'Base Layers',
#  b'Bastien',
#  b'Bath',
#  b'Beca Michele',
#  b'Beeko',
#  b'Belts',
#  b'Benjamin Walk',
#  b'Bensimon',
#  b'Bibi',
#  b'Bite',
#  b'Blokes',
#  b'Bottoms',
#  b'Boxing',
#  b'Braces, Splints & Supports',
#  b'COSMOSIS',
#  b'Cargo Shorts',
#  b'Carvela',
#  b'Casual Socks',
#  b'Christian Dior',
#  b'Christine & Kelly',
#  b'Chubasco',
#  b'Chuches',
#  b'Clothing & Closet Storage',
#  b'Clutches',
#  b'Cogent',
#  b'Cold Weather Gloves',
#  b'Compression Shorts',
#  b'Compression Socks',
#  b'Computers & Accessories',
#  b'Cover-Ups',
#  b'Crampons',
#  b'Cross-Body Bags',
#  b'Cydwoq',
#  b'Cynthia Rowley',
#  b'DAPH DAPH',
#  b'Dassler by PUMA Black Label',
#  b'David Spencer',
#  b'DeWALT',
#  b'Destroy Junior',
#  b'Diving Lures',
#  b'Dolls',
#  b'Dolls & Accessories',
#  b'Dresses & Jumpers',
#  b'Due Farina',
#  b'Duffs',
#  b'ES',
#  b'Echo',
#  b'Eddie Moran',
#  b'Eileen Shields',
#  b'Electric',
#  b'Electrical',
#  b'Electronics',
#  b'Elliott Lucca',
#  b'Emilio Pucci',
#  b'Enigma',
#  b'Enzo',
#  b'Eric Javits',
#  b'Etro',
#  b'Evening Bags',
#  b'Face',
#  b'Ferrari',
#  b'Fessura',
#  b'Fifi & Elvis',
#  b'Fire & Safety',
#  b'First Kiss',
#  b'Food Service',
#  b'Foot Care',
#  b'Foot Petals',
#  b'Foot Supports',
#  b'Fragrance',
#  b'Furla',
#  b'GBB',
#  b'Gant',
#  b'Gardening & Lawn Care',
#  b'Gear Box',
#  b'Georgia Boot',
#  b'Giorgio Armani',
#  b'Giraudon',
#  b'Givenchy',
#  b'Glory Chen',
#  b'Gloves & Mittens',
#  b'Green Tech',
#  b'Gretta',
#  b'Gucci',
#  b'Handcuffs',
#  b'Handcuffs & Restraints',
#  b'Hard Lures',
#  b'Health Care',
#  b'Hilary Radley',
#  b'Home & Kitchen',
#  b'Hugo Boss',
#  b'Hypnotic',
#  b'Inline & Roller Skating',
#  b'Inline Skates',
#  b'Inserts & Insoles',
#  b'Insoles',
#  b'Insulated & Down Vests',
#  b'Interior Accessories',
#  b'Joseph Allen',
#  b'Just Cavalli',
#  b'Karhu',
#  b'Katia Lombardo',
#  b'Kayland',
#  b'Kenzo',
#  b'Killah',
#  b'Kimel',
#  b'Kitchen & Dining',
#  b'Kitchen Utensils & Gadgets',
#  b'Lafuma',
#  b'Land Rover',
#  b'Laptop & Netbook Computer Accessories',
#  b'Latico',
#  b'Lauren Merkin',
#  b'Leather & Suede',
#  b'Leather Island by Bill Lavin',
#  b'Leatherbay',
#  b'Leg & Foot Supports',
#  b'Leg Avenue',
#  b'Leggings',
#  b'Leotards',
#  b'Light Switches',
#  b'Limited-time Offer',
#  b'Linea Blu by Cordani',
#  b'Lotto',
#  b'Lures, Baits & Attractants',
#  b'Magrit',
#  b'Marc Jacobs',
#  b'Maruti',
#  b'Materia Prima',
#  b'Meat & Poultry Tools',
#  b'Melania',
#  b'Messenger Bags',
#  b'Mighty Joe',
#  b'Minibel',
#  b'Missoni',
#  b'Mitzy',
#  b'More Accessories',
#  b'Moreschi',
#  b'Morgan & Milo',
#  b'Moschino',
#  b'Mountaineering Boots',
#  b'Mountaineering Hard Shell',
#  b'Natural Steps',
#  b'Neckties',
#  b'New Rock',
#  b'Nick & Nora',
#  b'Nina Dolls',
#  b'PROJECTART',
#  b'PUR',
#  b'Pablosky',
#  b'Painting Supplies & Wall Treatments',
#  b'Patio, Lawn & Garden',
#  b'Paul Mayer Attitudes',
#  b'Peter Kaiser',
#  b'Phat Farm',
#  b'Pliner Jrs',
#  b'Po-Zu',
#  b'Polishes & Dyes',
#  b'Posters & Prints',
#  b'Prada',
#  b'Prescription Eyewear Frames',
#  b'RJ Girl',
#  b'ROXX',
#  b'Racing Apparel',
#  b'Racing Suits',
#  b'Rangoni',
#  b'Ras',
#  b'Red Tape',
#  b'Rex for Robert Wayne',
#  b'Rhinestones & Sequins',
#  b'Richter',
#  b'Roberto Cavalli',
#  b'Rochester',
#  b'Rubber Duck',
#  b'Rugby',
#  b'SIDI',
#  b'Safety',
#  b'Safety Boots',
#  b'Satch & Sol',
#  b'Schmoove',
#  b'Sets',
#  b'Sewing',
#  b'Shannon Britt',
#  b'Shells & Soft Shells',
#  b'Shoe Decoration Charms',
#  b'Shoe Racks & Trees',
#  b'Shoulder Bags',
#  b'Skin Care',
#  b'Skorts',
#  b'Skullies & Beanies',
#  b'Sleep & Lounge',
#  b'Slippers International',
#  b'Smith & Wesson',
#  b'Snow & Ice Equipment',
#  b'Spring Court',
#  b'Springboost',
#  b'Standing Comfort',
#  b'Stevies',
#  b'Storage & Organization',
#  b'Surfing',
#  b'Surfing Booties',
#  b'Sutor Mantellassi',
#  b'Swimsuits & Cover Ups',
#  b'Switches',
#  b'TUMI',
#  b'Tactical & Duty',
#  b'Team Sports',
#  b'Thermal Underwear',
#  b'Track & Active Jackets',
#  b'Track Pants',
#  b'Transformers',
#  b'Treesje',
#  b'Treksta',
#  b'Trim & Embellishments',
#  b'Tuxedo Pants',
#  b'VOX',
#  b'Vael Project',
#  b'Veggies',
#  b'Venettini',
#  b'Vera Bradley',
#  b'Vivanz',
#  b'Wall Stickers & Murals',
#  b'Wall Switches',
#  b'Wallets',
#  b'Wallets, Card Cases & Money Organizers',
#  b'Warmbat',
#  b'Wigs',
#  b'Woolenstocks',
#  b'Workout Shorts',
#  b'World Industries',
#  b'Wristlets',
#  b'Z7',
#  b'Zumfoot',
#  b'botkier',
#  b'encanto',
#  b'espace',
#  b'justsweet',
#  b'piloti'}

# %%
BOTTOM_CATS = [ b'Pants & Capris',
b'Active Shorts',
b'Skirt Suits',
b'Jeans',
b'Pants',
b'Active Skirts',
b'Shorts',
b'Suit Pants',
b'Active Pants',
b'Bottoms',
b'Cargo Shorts',
b'Leggings',
b'Track Pants',
b'Skirts',
b'Skirt Sets',
b'Skirts, Scooters & Skorts']

# %%
TOP_CATS = [ b'Fashion Hoodies & Sweatshirts',
b'Blazers & Jackets',
b'Cardigan',
b'Fashion Sweatshirts',
b'Polos',
b'Cardigans',
b'Windbreakers',
b'Outerwear & Coats',
b'Active Sweatshirts',
b'Hoodies',
b'Jumpsuits, Rompers & Overalls',
b'Suits & Blazers',
b'Button-Down & Dress Shirts',
b'Tuxedo Shirts',
b'Tops',
b'Tees',
b'Fleece Jackets',
b'Button-Down Shirts',
b'Tank Tops',
b'Jumpsuits & Rompers',
b'Casual Button-Down Shirts',
b'Sweatshirts',
b'Pullover',
b'Jackets & Coats',
b'Tanks & Camis',
b'Tanks Tops',
b'Knits & Tees',
b'Fashion Hoodies',
b'Dress Shirts',
b'Overalls',
b'Active Shirts & Tees',
b'Shirts',
b'Overalls & Coveralls',
b'Denim Jackets',
b'Varsity Jackets',
b'Suit Jackets',
b'Fleece Vests',
b'Jackets & Vests',
b'Tuxedo Jackets',
b'Lightweight Jackets',
b'Tops & Tees',
b'Pullovers',
b'Coats & Jackets',
b'Blouses & Button-Down Shirts',
b'Blazers',
b'Quilted Lightweight Jackets',
b'T-Shirts',
b'Polo Shirts',
b'Sweaters',
b'Henleys',
b'Jackets',
b'Dress Coats',
b'Sport Coats & Blazers',
b'Active Hoodies',
b'Active Vests',
b'Dresses & Jumpers',
b'Insulated & Down Vests',
b'Track & Active Jackets',
b'Dress',
b'Blouses',
b'Dresses']

# %%
SHOE_CATS = [ b'Riding Boots',
b'Oxfords',
b'Loafers & Slip-Ons',
b'Boots',
b'Equestrian Sport Boots',
b'BC Footwear',
b'Uniform Dress Shoes',
b'Hiking Boots',
b'Safety Shoes',
b'Shoes',
b'Backpacking Boots',
b'Comfort Shoes',
b'Rain Footwear',
b'Rachel Shoes',
b'Fashion Sneakers',
b'Sport Sandals',
b'Sneakers',
b'Loafers',
b'Rain Boots',
b'Footwear',
b'Rainbow Sandals',
b'crocs',
b'Slippers',
b'Hiking Shoes',
b'Shoe & Boot Trees',
b'Safety Footwear',
b'Safety Boots',
b'Flats']

# %%
MALE_CATS = [ b'Men', b'Boys']
FEMALE_CATS = [ b'Women', b'Girls']

# %%
labeled_data = []
labels = []

for key, value in Item.items():
    catLists = value[b'categories']
    tempSet = set()
    for catList in catLists:
        for cat in catList:
            tempSet.add(cat)
    
    gender = 2
    piece = 3
    for cat in tempSet:
        if cat in MALE_CATS:
            gender = 0
        elif cat in FEMALE_CATS:
            gender = 1
        elif cat in TOP_CATS:
            piece = 0
        elif cat in BOTTOM_CATS:
            piece = 1
        elif cat in SHOE_CATS:
            piece = 2
    
    if gender == 0 and piece == 0:
        labels.append('men top')
    elif gender == 0 and piece == 1:
        labels.append('men bottom')
    elif gender == 0 and piece == 2:
        labels.append('men shoe')
    elif gender == 1 and piece == 0:
        labels.append('women top')
    elif gender == 1 and piece == 1:
        labels.append('women bottom')
    elif gender == 1 and piece == 2:
        labels.append('women shoe')
    if gender != 2 and piece != 3:                
        labeled_data.append(value)

# %%
class ClothingDataset(Dataset):
    def __init__(self, data, labels):
        self.labels = labels
        self.data = data
        
    def __getitem__(self, index):
        imgBytes = self.data[index][b'imgs']
        img = np.uint8(np.asarray(Image.open(BytesIO(imgBytes)).convert('RGB').resize((224,224))))
        label = self.labels[index]
        return img, label

    def __len__(self):
        return len(labels)

# %%
training_data = labeled_data[0:114882]
training_labels = labels[0:114882]
validation_data = labeled_data[114882:147706]
validation_labels = labels[114882:147706]

# %%
'''
MAKE DATA ITERABLE
'''
params = {'batch_size': 64,
          'shuffle': True,
         'num_workers': 6}

training_set = ClothingDataset(training_data, training_labels)
training_generator = DataLoader(training_set, **params)

params['shuffle'] = False
validation_set = ClothingDataset(validation_data, validation_labels)
validation_generator = DataLoader(validation_set, **params)

# %%
# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
'''
Model is already defined. Lets instantiate it from torchvision
'''
resnet18 = models.resnet18()

# %%
'''
Instantiate loss class
'''
criterion = nn.CrossEntropyLoss()

# %%
'''
Instantiate optimizer class
'''
learning_rate = 0.01

optimizer = torch.optim.SGD(resnet18.parameters(), lr=learning_rate)

# %%
n_iters = 15387 # for 6 epochs
num_epochs = n_iters / (len(training_set) / 64)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 6

# %%
'''
Train the model
'''
iter = 0
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(training_generator):
        # Load images with gradient accumulation capabilities
        trans = transforms.ToTensor()
        images = trans(images)
        images = images.view(-1, 224*224).requires_grad_()

        # Clear gradients w.r.t. parameters
        optimizer.zero_grad()

        # Forward pass to get output/logits
        outputs = model(images)

        # Calculate Loss: softmax --> cross entropy loss
        loss = criterion(outputs, labels)

        # Getting gradients w.r.t. parameters
        loss.backward()

        # Updating parameters
        optimizer.step()

        iter += 1

        if iter % 1538 == 0:
            # Calculate Accuracy         
            correct = 0
            total = 0
            # Iterate through test dataset
            for images, labels in validation_generator:
                # Load images with gradient accumulation capabilities
                images = images.view(-1, 224*224).requires_grad_()

                # Forward pass only to get logits/output
                outputs = model(images)

                # Get predictions from the maximum value
                _, predicted = torch.max(outputs.data, 1)

                # Total number of labels
                total += labels.size(0)

                # Total correct predictions
                correct += (predicted == labels).sum()

            accuracy = 100 * correct / total

            # Print Loss
            print('Iteration: {}. Loss: {}. Accuracy: {}'.format(iter, loss.item(), accuracy))
# Out:
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\message.c:4018)
#     PyErr_CheckSignals()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-109-fa7199e23d99> in <module>()
#       4 iter = 0
#       5 for epoch in range(num_epochs):
# ----> 6     for i, (images, labels) in enumerate(training_generator):
#       7         # Load images with gradient accumulation capabilities
#       8         trans = transforms.ToTensor()
#
# C:\Users\HuyenLe\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     817
#     818     def __iter__(self):
# --> 819         return _DataLoaderIter(self)
#     820
#     821     def __len__(self):
#
# C:\Users\HuyenLe\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     558                 #     before it starts, and __del__ tries to join but will get:
#     559                 #     AssertionError: can only join a started process.
# --> 560                 w.start()
#     561                 self.index_queues.append(index_queue)
#     562                 self.workers.append(w)
#
# C:\Users\HuyenLe\Anaconda3\lib\multiprocessing\process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         _children.add(self)
#
# C:\Users\HuyenLe\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     210     @staticmethod
#     211     def _Popen(process_obj):
# --> 212         return _default_context.get_context().Process._Popen(process_obj)
#     213
#     214 class DefaultContext(BaseContext):
#
# C:\Users\HuyenLe\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     311         def _Popen(process_obj):
#     312             from .popen_spawn_win32 import Popen
# --> 313             return Popen(process_obj)
#     314
#     315     class SpawnContext(BaseContext):
#
# C:\Users\HuyenLe\Anaconda3\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      64             try:
#      65                 reduction.dump(prep_data, to_child)
# ---> 66                 reduction.dump(process_obj, to_child)
#      67             finally:
#      68                 context.set_spawning_popen(None)
#
# C:\Users\HuyenLe\Anaconda3\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      57 def dump(obj, file, protocol=None):
#      58     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 59     ForkingPickler(file, protocol).dump(obj)
#      60
#      61 #
#
# BrokenPipeError: [Errno 32] Broken pipe
